# %% [markdown]
# # Lancoz Algorithm, Ground-State: Heisenberg model (J1-J1 model (J = 0))
#
# > **Code basé sur le tutoriel officiel de NetKet :**
# > G. Carleo et F. Vicentini, *Ground-State: Heisenberg model*, NetKet Tutorials.
# > [En ligne]. Disponible : [https://netket.readthedocs.io/en/latest/tutorials/gs-heisenberg.html](https://netket.readthedocs.io/en/latest/tutorials/gs-heisenberg.html)

# %%
import tqdm as tqdm
import netket as nk
import time
import numpy as np
from tqdm import tqdm
import os
import json
import sys

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
# %load_ext autoreload
# %autoreload 2

from src.lanczos_krylov import Krylov_method_with_bootstrap
from src.utils import *
from src.plot.plotlib import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
verbose = True

# %%
# Defining the Hamiltonian 
L = 4
graph = nk.graph.Hypercube(length=L, n_dim=2, pbc=True, max_neighbor_order=2) # correspond a J2 = 0
hi = nk.hilbert.Spin(s=0.5, total_sz=0, N=graph.n_nodes)
ha = 0.25 * nk.operator.Heisenberg(hilbert=hi, graph=graph, sign_rule=[True, False], J =[1.0, 0.5]) # correspond a J2 = 0
plot_netket_graph(graph, layout='square_pbc')

# %%
# Exact Diagonalization
evals = nk.exact.lanczos_ed(ha, compute_eigenvectors=False)
exact_gs_energy = evals[0]
print("The exact ground-state energy is E0=", exact_gs_energy)
print("The exact energy per site =", exact_gs_energy / L**2)
# Out:
# The exact ground-state energy is E0= -8.457923351394859
# The exact energy per site = -0.5286202094621787

# %%
# hyperparameters 
diag_shift = 1e-4           # The diagonal regularization parameter
learning_rate = 1e-2        # learning rate
n_samples = 2048            # number of samples (aug : pour avoir des stats physiques), 4096
n_iter = 200                # number of iterations # 600
alpha = 1                   # feature density. Number of features equal to alpha * input.shape[-1]
num_it = 1000               # number of iterations for the Krylov method

# data directory
data_file = f"../../datas/2D_4x4/datas_krylov_iter_hypercube_{n_iter}"
dir_init = data_file + "/RBM_init"
if not os.path.exists(data_file):
    os.makedirs(data_file)
    print(f"Le dossier '{data_file}' vient d'être créé.")
else:
    print(f"Le dossier '{data_file}' existe déjà.")

hyperparameters = {
    "data_file": data_file,
    "dir_init": dir_init,
    "diag_shift": diag_shift,
    "learning_rate": learning_rate,
    "n_samples": n_samples,
    "n_iter": n_iter,
    "feature_density_alpha": alpha,
    "num_it": num_it,
    "L": L
}
json_path = os.path.join(data_file, "hyperparameters.json")

with open(json_path, 'w') as f:
    json.dump(hyperparameters, f, indent=4) 

print(f"Paramètres sauvegardés avec succès dans {json_path}")
# Out:
# Le dossier '../../datas/2D_4x4/datas_krylov_iter_hypercube_200' existe déjà.
# Paramètres sauvegardés avec succès dans ../../datas/2D_4x4/datas_krylov_iter_hypercube_200/hyperparameters.json

# %%
# Learning with a Restricted Boltzmann Machine (RBM)
model = nk.models.RBM(alpha=alpha, param_dtype=np.complex128)
sampler = nk.sampler.MetropolisExchange(hilbert=hi, graph=graph)
optimizer = nk.optimizer.Sgd(learning_rate=learning_rate)
vs = nk.vqs.MCState(sampler, model, n_samples=n_samples)
gs = nk.driver.VMC_SR(
    hamiltonian=ha, 
    optimizer=optimizer, 
    diag_shift=diag_shift, 
    variational_state=vs
)
gs.run(out=data_file + "/VMC_datas", n_iter=n_iter)
# Out:
# Automatic SR implementation choice:  QGT
#  19%|█▉        | 38/200 [00:02<00:10, 15.62it/s, Energy=-7.955 ± 0.021 [σ²=8.1e-01, R̂=1.004]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 12
#       5 vs = nk.vqs.MCState(sampler, model, n_samples=n_samples)
#       6 gs = nk.driver.VMC_SR(
#       7     hamiltonian=ha,
#       8     optimizer=optimizer,
#       9     diag_shift=diag_shift,
#      10     variational_state=vs
#      11 )
# ---> 12 gs.run(out=data_file + "/VMC_datas", n_iter=n_iter)
#
# File ~/Desktop/EPFL/MA2/TPIV/project-tp/.env/lib/python3.11/site-packages/netket/driver/abstract_variational_driver.py:348, in AbstractVariationalDriver.run(self, n_iter, out, obs, step_size, show_progress, save_params_every, write_every, callback, timeit)
#     346 for step in self.iter(n_iter, step_size):
#     347     log_data = self.estimate(obs)
# --> 348     self._log_additional_data(log_data, step)
#     350     # if the cost-function is defined then report it in the progress bar
#     351     if self._loss_stats is not None:
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/EPFL/MA2/TPIV/project-tp/.env/lib/python3.11/site-packages/netket/_src/driver/vmc_sr.py:488, in VMC_SR._log_additional_data(self, log_dict, step)
#     486 # Always log the acceptance.
#     487 if hasattr(self.state, "sampler_state"):
# --> 488     acceptance = getattr(self.state.sampler_state, "acceptance", None)
#     489     if acceptance is not None:
#     490         log_dict["acceptance"] = acceptance
#
# File ~/Desktop/EPFL/MA2/TPIV/project-tp/.env/lib/python3.11/site-packages/netket/sampler/metropolis.py:104, in MetropolisSamplerState.acceptance(self)
#      97 @property
#      98 def acceptance(self) -> float | None:
#      99     """The fraction of accepted moves across all chains.
#     100
#     101     The rate is computed since the last reset of the sampler.
#     102     Will return None if no sampling has been performed since then.
#     103     """
# --> 104     if self.n_steps == 0:
#     105         return None
#     107     return self.n_accepted / self.n_steps
#
# File ~/Desktop/EPFL/MA2/TPIV/project-tp/.env/lib/python3.11/site-packages/jax/_src/array.py:295, in ArrayImpl.__bool__(self)
#     293 def __bool__(self):
#     294   core.check_bool_conversion(self)
# --> 295   return bool(self._value)
#
# File ~/Desktop/EPFL/MA2/TPIV/project-tp/.env/lib/python3.11/site-packages/jax/_src/profiler.py:384, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     381 @wraps(func)
#     382 def wrapper(*args, **kwargs):
#     383   with TraceAnnotation(name, **decorator_kwargs):
# --> 384     return func(*args, **kwargs)
#
# File ~/Desktop/EPFL/MA2/TPIV/project-tp/.env/lib/python3.11/site-packages/jax/_src/array.py:641, in ArrayImpl._value(self)
#     638 if self._npy_value is None:
#     639   # addressable_device_list can be empty. If it's empty, we will error below
#     640   if self.is_fully_replicated and self.sharding.has_addressable_devices:
# --> 641     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#     642     npy_value.flags.writeable = False
#     643     if did_copy:
#
# KeyboardInterrupt:

# %%
with open(data_file + "/VMC_datas.log") as f:
    data = json.load(f)

if verbose:
    plot_VMC(f"{data_file}/VMC_datas.log", exact_gs_energy, save_fig=True, fig_name=f"{data_file}/VMC_init_metrics.png")
# Out:
# ✅ Figure saved as ../../datas/2D_4x4/datas_krylov_iter_hypercube_200/VMC_init_metrics.png

# %%
results_eL = np.zeros(num_it)
results_e0 = np.zeros(num_it)
results_sigma_e0 = np.zeros(num_it) 
results_sigma_eL = np.zeros(num_it)
results_time = np.zeros(num_it) 

pbar = tqdm(range(num_it))

start_time_global = time.perf_counter()

for i in pbar:

    vs.sample() 
    
    el, e0, sigma_e0, sigma_eL = Krylov_method_with_bootstrap(
        vs, ha
    )

    elapsed_time = time.perf_counter() - start_time_global
    
    results_eL[i] = el
    results_e0[i] = e0
    results_sigma_e0[i] = sigma_e0
    results_sigma_eL[i] = sigma_eL
    results_time[i] = elapsed_time

    pbar.set_postfix(el=f"{el:.5f} ± {sigma_eL:.5f}", exact=f"{exact_gs_energy:.5f}")


el_valides = results_eL[~np.isnan(results_eL)]

if verbose :
    print(f"Mean of the means (E0) : {np.mean(results_e0):.8f}")
    print(f"Std of the means (E0)  : {np.std(results_e0, ddof=1):.8f}")
    print(f"Mean  (EL)             : {np.mean(el_valides):.8f}")
    print(f"Std (EL)               : {np.std(el_valides, ddof=1):.8f}")
    print(f"Exact Energy           : {exact_gs_energy}")
# Out:
# 100%|██████████| 1000/1000 [22:11<00:00,  1.33s/it, el=-11.21132 ± 0.00000, exact=-11.22848]
# Mean of the means (E0) : -11.17667225
# Std of the means (E0)  : 0.01264198
# Mean  (EL)             : -11.22752347
# Std (EL)               : 0.01537003
# Exact Energy           : -11.22848320842885

# %%
save_simulation_logs(
    target_dir=data_file,
    n_iterations=num_it,          
    e0_array=results_e0,      
    sigma_e0_array=results_sigma_e0, 
    el_array=results_eL,         
    sigma_el_array=results_sigma_eL,
    time_array=results_time,
    exact_energy=exact_gs_energy
)
# Out:
# Simulation logs successfully saved to: ../../datas/2D_4x4/datas_krylov_iter_hypercube_200/simulation_results.json

# %%
plot_energy_distribution(
    el_valides=el_valides, 
    results_e0=results_e0, 
    exact_gs_energy=exact_gs_energy, 
    data_file=data_file,
    bins=40 
)

# %%
plot_zero_variance_extrapolation(
    results_e0 = results_e0, 
    results_sigma_e0 = results_sigma_e0, 
    el_valides = el_valides, 
    results_sigma_eL = results_sigma_eL, 
    exact_gs_energy = exact_gs_energy, 
    L = L, 
    data_file = data_file
)
# Out:
# Graphique d'extrapolation sauvegardé sous : ../../datas/2D_4x4/datas_krylov_iter_hypercube_200/extrapolation_plot.png
# --- Extrapolation Results (per site) ---
# Extrapolated Energy (x=0) : -2.81030109
# Exact Energy              : -2.80712080
# Absolute Error            : 3.18029031e-03
# ----------------------------------------
